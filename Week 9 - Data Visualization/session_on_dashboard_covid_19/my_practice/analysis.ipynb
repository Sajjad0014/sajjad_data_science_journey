# %%
import pandas as pd
import numpy as np

# %%
patients = pd.read_csv('IndividualDetails.csv')
print(patients.shape)
patients.head()
# Out:
# (8472, 12)
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# ...

# %%
patients.current_status.value_counts()
# Out:
# current_status
# Hospitalized    8301
# Recovered        139
# Deceased          30
# Migrated           1
# Name: count, dtype: int64

# %%
total = patients.current_status.count()
total
# Out:
# 8471

# %%
active = patients.query('current_status == "Hospitalized"').shape[0]
recovered = patients.query('current_status == "Recovered"').shape[0]
deaths = patients.query('current_status == "Deceased"').shape[0]
print(active, recovered, deaths)
# Out:
# 8301 139 30

# %%
patient_bar = patients.detected_state.value_counts().reset_index()
patient_bar
# Out:
#                  detected_state  count
# 0                   Maharashtra   1761
# 1                         Delhi   1069
# 2                    Tamil Nadu    969
# 3                     Rajasthan    700
# 4                Madhya Pradesh    529
# 5                     Telangana    503
# 6                       Gujarat    468
# 7                 Uttar Pradesh    452
# 8                Andhra Pradesh    405
# 9                        Kerala    373
# 10                    Karnataka    226
# 11            Jammu and Kashmir    224
# 12                      Haryana    179
# 13                       Punjab    158
# 14                  West Bengal    134
# 15                        Bihar     64
# 16                       Odisha     54
# 17                  Uttarakhand     35
# 18             Himachal Pradesh     32
# 19                        Assam     29
# 20                 Chhattisgarh     25
# 21                   Chandigarh     19
# 22                    Jharkhand     17
# ...

# %%
no_of_patients = patients.query('current_status == "Recovered"')
pbar = no_of_patients.detected_state.value_counts().reset_index()
pbar
# Out:
#       detected_state  count
# 0             Kerala     58
# 1          Karnataka     39
# 2            Haryana     12
# 3      Uttar Pradesh      6
# 4         Tamil Nadu      6
# 5          Rajasthan      3
# 6        West Bengal      3
# 7              Delhi      2
# 8        Maharashtra      2
# 9     Andhra Pradesh      2
# 10         Telangana      1
# 11      Chhattisgarh      1
# 12       Uttarakhand      1
# 13           Gujarat      1
# 14  Himachal Pradesh      1
# 15           Manipur      1
