# %% [markdown]
# **Problem:**
#
# You are given the following dataset:
# 1. **Audible Data** : https://1drv.ms/u/s!AiqdXCxPTydhoog8ckLN-6Cw55fzIg?e=EWgZ5d
#
# Your task is to:
# - Find the problems with the datasets.
# - Define the Data Quality Dimensions.
# - Try to clean the datasets.

# %%
import pandas as pd

# %%
audible = pd.read_csv('audible_uncleaned.csv')
print(audible.shape)
audible.head()
# Out:
# (87489, 8)
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    4/8/2008  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    1/5/2018  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins   6/11/2020  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins   5/10/2021  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# 3   4.5 out of 5 stars12 ratings   615
# 4  4.5 out of 5 stars181 ratings   820

# %% [markdown]
# ### 1. Write a summary for your data
#
# With the trend toward audiobooks growing, I gathered this data to understand how the audiobook market has been growing over the years. From authors of audiobooks to release dates, the data represents the important details of audiobooks from 1998 till 2025 (pre-planned releases).
#
# I have yet to find a great audiobooks dataset and hence the urge to make a dataset that provides us with information on the basics and the history of audiobooks. I look to improve the dataset with more details in the near future.

# %% [markdown]
# ### 2. Write Column descriptions
#
# #### **Table** -> `audible`:
# - name - names of the audiobooks
# - author - authors of that audiobook
# - narrator - narrator of that audio book
# - time - runtime
# - releasedate - date of release
# - language - what language it is released in
# - stars - ratings out of 5 and number of people voted
# - price - price in rupees

# %% [markdown]
# ### 3. Add any additional information

# %% [markdown]
# ### Types of Assessment
#
# There are 2 types of assessment styles:
# - Manual - Looking through the data manually in google sheets
# - Programmatic - By using pandas function such as info(), describe() or sample()
#
# #### Steps in Assessment
# There are 2 steps involved in Assessment
# - Discover
# - Document

# %% [markdown]
# ### Issues with the dataset
# 1. Dirty Data (Quality Issues)
# - time is not in minutes format `consistency`
# - release date format is sometimes written with // or -- `consistency`
# - stars column is not consistent and is mixed with ratings `consistency`
# -
#
# 2. Messy Data (Structural Issues)
# - author has unnecessary Writtenby: written in it
# - narrator has unnecessary Narratedby: written in it
# - price has some values in int and some in float
# - There is no space between author names and narrator names
# - price column name does not have what the currency
# -  change data types of release date to datetime,
# - language to categorical
# - and time stars ratings price to int or float

# %% [markdown]
# #### Automatic Assessment
# - head and tail
# - sample
# - info
# - isnull
# - duplicated
# - describe

# %%
audible.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    4/8/2008  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    1/5/2018  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins   6/11/2020  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins   5/10/2021  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# 3   4.5 out of 5 stars12 ratings   615
# 4  4.5 out of 5 stars181 ratings   820

# %%
audible.tail()
# Out:
#                             name                    author  \
# 87484  Last Days of the Bus Club    Writtenby:ChrisStewart
# 87485                   The Alps   Writtenby:StephenO'Shea
# 87486       The Innocents Abroad       Writtenby:MarkTwain
# 87487      A Sentimental Journey  Writtenby:LaurenceSterne
# 87488                     Havana   Writtenby:MarkKurlansky
#
#                       narrator               time releasedate language  \
# 87484  Narratedby:ChrisStewart  7 hrs and 34 mins    9/3/2017  English
# 87485    Narratedby:RobertFass  10 hrs and 7 mins    21-02-17  English
# 87486     Narratedby:FloGibson  19 hrs and 4 mins    30-12-16  English
# 87487   Narratedby:AntonLesser   4 hrs and 8 mins    23-02-11  English
# 87488   Narratedby:FleetCooper    6 hrs and 1 min    7/3/2017  English
#
#                stars price
# 87484  Not rated yet   596
# 87485  Not rated yet   820
# 87486  Not rated yet   938
# 87487  Not rated yet   680
# 87488  Not rated yet   569

# %%
audible.sample(10)
# Out:
#                                                     name  \
# 38574                 资治通鉴 9 - 資治通鑑 9 [Zizhi Tongjian 9]
# 28253  Mitarbeitermotivation lernen & umsetzen - Das ...
# 23750                                      Howard's Gift
# 32569                                  Awakening Artemis
# 10608                        How Not to Network a Nation
# 83978                             La signora della morte
# 68976                             De l'ego au Moi Unique
# 15285                              Everyone's own Vienna
# 21874                             Living with No Excuses
# 46151                                       The Unspoken
#
#                             author                           narrator  \
# 38574  Writtenby:司马光-司馬光-SimaGuang  Narratedby:白云出岫-白雲出岫-Baiyunchuxiu
# 28253  Writtenby:ThorstenMössinger            Narratedby:CelinaBender
# 23750        Writtenby:EricSinoway           Narratedby:WilliamDufris
# 32569     Writtenby:VanessaChakour          Narratedby:VanessaChakour
# 10608     Writtenby:BenjaminPeters              Narratedby:DanaHickox
# 83978        Writtenby:JohnnyRosso            Narratedby:MorenoD'Isep
# 68976          Writtenby:MarcGafni         Narratedby:PhilippeJoannis
# 15285      Writtenby:MitsuyoKakuta              Narratedby:NahokoFort
# 21874       Writtenby:NoahGalloway            Narratedby:NoahGalloway
# 46151         Writtenby:IanK.Smith            Narratedby:AmirAbdullah
#
#                      time releasedate          language          stars  \
# 38574  33 hrs and 10 mins   12/2/2018  mandarin_chinese  Not rated yet
# 28253    1 hr and 16 mins   3/12/2021            german  Not rated yet
# 23750   9 hrs and 19 mins   2/10/2012           English  Not rated yet
# 32569  14 hrs and 27 mins   10/2/2022           English  Not rated yet
# 10608  10 hrs and 16 mins    25-08-16           English  Not rated yet
# 83978   4 hrs and 37 mins    17-06-20           italian  Not rated yet
# 68976   4 hrs and 29 mins    3/2/2017            french  Not rated yet
# 15285             17 mins   2/10/2014          japanese  Not rated yet
# 21874   7 hrs and 18 mins    24-08-16           English  Not rated yet
# 46151   8 hrs and 16 mins   1/10/2020           English  Not rated yet
#
#           price
# 38574  1,338.00
# 28253       233
# 23750       134
# 32569       888
# 10608       836
# 83978       267
# 68976       641
# 15285        32
# 21874       500
# 46151  1,008.00

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %%
audible.isnull().sum()
# Out:
# name           0
# author         0
# narrator       0
# time           0
# releasedate    0
# language       0
# stars          0
# price          0
# dtype: int64

# %%
audible.duplicated().sum()
# Out:
# 0

# %%
audible.describe()
# Out:
#                   name              author              narrator    time  \
# count            87489               87489                 87489   87489
# unique           82767               48374                 29717    2284
# top     The Art of War  Writtenby:矢島雅弘,石橋遊  Narratedby:anonymous  2 mins
# freq                20                 874                  1034     372
#
#        releasedate language          stars  price
# count        87489    87489          87489  87489
# unique        5058       36            665   1011
# top       16-05-18  English  Not rated yet    586
# freq           773    61884          72417   5533

# %%
audible['name'].duplicated().sum()
# Out:
# 4722

# %%
audible[audible.name.duplicated()]
# Out:
#                                              name  \
# 18                      Merlin Mission Collection
# 46     The Lightning Thief: Percy Jackson, Book 1
# 54                      Merlin Mission Collection
# 155                        Barbie - Superprincesa
# 273                           Barbie - Dreamtopia
# ...                                           ...
# 87443       Travels with a Donkey in the Cevennes
# 87456                                  Gettysburg
# 87457                                        Solo
# 87475                                  Wanderlust
# 87486                        The Innocents Abroad
#
#                                           author  \
# 18                     Writtenby:MaryPopeOsborne
# 46                         Writtenby:RickRiordan
# 54                     Writtenby:MaryPopeOsborne
# 155                             Writtenby:Mattel
# 273    Writtenby:Mattel,MartaCisaMuñoz-traductor
# ...                                          ...
# 87443             Writtenby:RobertLouisStevenson
# 87456                       Writtenby:JeffShaara
# 87457                         Writtenby:PenHadow
# 87475                   Writtenby:ElisabethEaves
# 87486                        Writtenby:MarkTwain
#
#                             narrator                time releasedate language  \
# 18        Narratedby:MaryPopeOsborne  10 hrs and 18 mins    2/5/2017  English
# 46            Narratedby:WalterLewis   3 hrs and 51 mins    13-01-10  English
# 54        Narratedby:MaryPopeOsborne  13 hrs and 24 mins    2/5/2017  English
# 155    Narratedby:VanessaPérezJurado             29 mins    7/3/2022  spanish
# 273         Narratedby:MiriamMonlleo             21 mins    31-01-22  catalan
# ...                              ...                 ...         ...      ...
# 87443         Narratedby:DenisLawson   2 hrs and 51 mins    13-05-08  English
# 87456       Narratedby:RobertsonDean    1 hr and 12 mins    26-03-07  English
# 87457            Narratedby:PenHadow    3 hrs and 5 mins    14-02-05  English
# 87475         Narratedby:ErinBennett   9 hrs and 51 mins    26-02-14  English
# 87486           Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
#
#                             stars     price
# 18     5 out of 5 stars11 ratings  1,256.00
# 46      4 out of 5 stars4 ratings       615
# 54      5 out of 5 stars8 ratings  1,256.00
# 155                 Not rated yet        38
# 273                 Not rated yet        38
# ...                           ...       ...
# 87443               Not rated yet       569
# 87456               Not rated yet       200
# 87457               Not rated yet       615
# 87475               Not rated yet       668
# 87486               Not rated yet       938
#
# [4722 rows x 8 columns]

# %%
audible[['name', 'time']].duplicated().sum()
# Out:
# 238

# %%
audible[audible[['name', 'time']].duplicated()]
# Out:
#                                        name  \
# 273                     Barbie - Dreamtopia
# 510    Los Pitufos - Historias de 3 minutos
# 1882                     Egg Marks the Spot
# 2195                                 Camels
# 2457                                  Jaime
# ...                                     ...
# 85103                           Schneeriese
# 85175                              Stronger
# 86352                Neither Here Nor There
# 87239                          Tee and Tour
# 87258                          Tee and Tour
#
#                                             author  \
# 273      Writtenby:Mattel,MartaCisaMuñoz-traductor
# 510    Writtenby:Peyo,RaquelLuqueBenitez-traductor
# 1882                       Writtenby:AmyTimberlake
# 2195                           Writtenby:RoseDavin
# 2457                      Writtenby:LeandroCabrera
# ...                                            ...
# 85103                       Writtenby:SusanKreller
# 85175                      Writtenby:EricaMarselas
# 86352                         Writtenby:BillBryson
# 87239                           Writtenby:Tee,Tour
# 87258                           Writtenby:Tee,Tour
#
#                                           narrator               time  \
# 273                       Narratedby:MiriamMonlleo            21 mins
# 510                    Narratedby:GuillermoMontoya            34 mins
# 1882                     Narratedby:MichaelBoatman  3 hrs and 54 mins
# 2195                          Narratedby:Anonymous             2 mins
# 2457                      Narratedby:MarianoPrince            11 mins
# ...                                            ...                ...
# 85103                   Narratedby:ConstanzeWeinig  5 hrs and 17 mins
# 85175  Narratedby:AmyMelissaBentley,GrahamHalstead   9 hrs and 2 mins
# 86352                        Narratedby:BillBryson  5 hrs and 38 mins
# 87239                      Narratedby:SuzanneToren   2 hrs and 6 mins
# 87258                        Narratedby:KevinYoung   1 hr and 49 mins
#
#       releasedate language                        stars price
# 273      31-01-22  catalan                Not rated yet    38
# 510      17-01-22  spanish                Not rated yet    38
# 1882     14-09-21  English                Not rated yet   398
# 2195     21-02-22  English                Not rated yet    82
# 2457     4/3/2022  spanish                Not rated yet    65
# ...           ...      ...                          ...   ...
# 85103    2/9/2020   german                Not rated yet   535
# 85175  12/11/2019  English                Not rated yet   586
# 86352    1/4/2010  English  4.5 out of 5 stars2 ratings   615
# 87239    8/7/2004  English                Not rated yet   585
# 87258    30-06-04  English                Not rated yet   585
#
# [238 rows x 8 columns]

# %% [markdown]
# #### Making a copy

# %%
audible_df = audible.copy()

# %%
audible_df['author'] = audible_df['author'].str.split(':').str.get(1)
audible_df['narrator'] = audible_df['narrator'].str.split(':').str.get(1)
audible_df.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator                time releasedate language  \
# 0      BillLobely   2 hrs and 20 mins    4/8/2008  English
# 1   RobbieDaymond   13 hrs and 8 mins    1/5/2018  English
# 2      DanRussell    2 hrs and 3 mins   6/11/2020  English
# 3  SoneelaNankani  11 hrs and 16 mins   5/10/2021  English
# 4  JesseBernstein              10 hrs    13-01-10  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# 3   4.5 out of 5 stars12 ratings   615
# 4  4.5 out of 5 stars181 ratings   820

# %%
import re


# Define a function to split based on capitalization pattern
def split_name(name):
    # Use regular expression to split when a lowercase letter is followed by an uppercase letter
    parts = re.findall(r'[A-Z][a-z]*', name)

    # Safely return first and last name or None if missing
    if len(parts) == 2:
        return parts[0], parts[1]  # Both first and last names
    elif len(parts) == 1:
        return parts[0], None  # Only first name available
    else:
        return None, None  # Handle any unexpected cases

# %%
split_name('DavidWarner')
# Out:
# ('David', 'Warner')

# %%
audible_df[['author_first_name', 'author_last_name']] = audible_df['author'].apply(lambda x: pd.Series(split_name(x)))

# %%
audible_df.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator                time releasedate language  \
# 0      BillLobely   2 hrs and 20 mins    4/8/2008  English
# 1   RobbieDaymond   13 hrs and 8 mins    1/5/2018  English
# 2      DanRussell    2 hrs and 3 mins   6/11/2020  English
# 3  SoneelaNankani  11 hrs and 16 mins   5/10/2021  English
# 4  JesseBernstein              10 hrs    13-01-10  English
#
#                            stars price author_first_name author_last_name
# 0     5 out of 5 stars34 ratings   468          Geronimo          Stilton
# 1   4.5 out of 5 stars41 ratings   820              Rick          Riordan
# 2   4.5 out of 5 stars38 ratings   410              Jeff           Kinney
# 3   4.5 out of 5 stars12 ratings   615              Rick          Riordan
# 4  4.5 out of 5 stars181 ratings   820              Rick          Riordan

# %%
audible_df[['narrator_first_name', 'narrator_last_name']] = audible_df['narrator'].apply(
    lambda x: pd.Series(split_name(x)))
audible_df.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator                time releasedate language  \
# 0      BillLobely   2 hrs and 20 mins    4/8/2008  English
# 1   RobbieDaymond   13 hrs and 8 mins    1/5/2018  English
# 2      DanRussell    2 hrs and 3 mins   6/11/2020  English
# 3  SoneelaNankani  11 hrs and 16 mins   5/10/2021  English
# 4  JesseBernstein              10 hrs    13-01-10  English
#
#                            stars price author_first_name author_last_name  \
# 0     5 out of 5 stars34 ratings   468          Geronimo          Stilton
# 1   4.5 out of 5 stars41 ratings   820              Rick          Riordan
# 2   4.5 out of 5 stars38 ratings   410              Jeff           Kinney
# 3   4.5 out of 5 stars12 ratings   615              Rick          Riordan
# 4  4.5 out of 5 stars181 ratings   820              Rick          Riordan
#
#   narrator_first_name narrator_last_name
# 0                Bill             Lobely
# 1              Robbie            Daymond
# 2                 Dan            Russell
# 3             Soneela            Nankani
# 4               Jesse          Bernstein

# %%
audible_df.drop(columns=['author', 'narrator'], inplace=True)

# %%
audible_df.head()
# Out:
#                                          name                time releasedate  \
# 0                  Geronimo Stilton #11 & #12   2 hrs and 20 mins    4/8/2008
# 1                            The Burning Maze   13 hrs and 8 mins    1/5/2018
# 2                                The Deep End    2 hrs and 3 mins   6/11/2020
# 3                        Daughter of the Deep  11 hrs and 16 mins   5/10/2021
# 4  The Lightning Thief: Percy Jackson, Book 1              10 hrs    13-01-10
#
#   language                          stars price author_first_name  \
# 0  English     5 out of 5 stars34 ratings   468          Geronimo
# 1  English   4.5 out of 5 stars41 ratings   820              Rick
# 2  English   4.5 out of 5 stars38 ratings   410              Jeff
# 3  English   4.5 out of 5 stars12 ratings   615              Rick
# 4  English  4.5 out of 5 stars181 ratings   820              Rick
#
#   author_last_name narrator_first_name narrator_last_name
# 0          Stilton                Bill             Lobely
# 1          Riordan              Robbie            Daymond
# 2           Kinney                 Dan            Russell
# 3          Riordan             Soneela            Nankani
# 4          Riordan               Jesse          Bernstein

# %%
audible_df['price'] = audible_df['price'].str.replace(',', '')

# %%
audible_df['price'] = audible_df['price'].str.replace('Free', '0')

# %%
audible_df['price'] = audible_df['price'].astype('float')

# %%
audible_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 87489 non-null  object
#  1   time                 87489 non-null  object
#  2   releasedate          87489 non-null  object
#  3   language             87489 non-null  object
#  4   stars                87489 non-null  object
#  5   price                87489 non-null  float64
#  6   author_first_name    53853 non-null  object
#  7   author_last_name     52398 non-null  object
#  8   narrator_first_name  62198 non-null  object
#  9   narrator_last_name   61071 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 6.7+ MB

# %%
audible_df.rename(columns={'price': 'price (in Rupees)'}, inplace=True)

# %%
def parse_date(date):
    if '/' in date:
        return pd.to_datetime(date, format='%d/%m/%Y', errors='coerce')
    elif '-' in date:
        return pd.to_datetime(date, format='%d-%m-%y', errors='coerce')
    else:
        return pd.NaT  # Return NaT for any other unrecognized formats

# %%
audible_df['releasedate'].head()
# Out:
# 0     4/8/2008
# 1     1/5/2018
# 2    6/11/2020
# 3    5/10/2021
# 4     13-01-10
# Name: releasedate, dtype: object

# %%
audible_df['releasedate'] = audible_df['releasedate'].apply(parse_date)

# %%
audible_df.head()
# Out:
#                                          name                time releasedate  \
# 0                  Geronimo Stilton #11 & #12   2 hrs and 20 mins  2008-08-04
# 1                            The Burning Maze   13 hrs and 8 mins  2018-05-01
# 2                                The Deep End    2 hrs and 3 mins  2020-11-06
# 3                        Daughter of the Deep  11 hrs and 16 mins  2021-10-05
# 4  The Lightning Thief: Percy Jackson, Book 1              10 hrs  2010-01-13
#
#   language                          stars  price (in Rupees)  \
# 0  English     5 out of 5 stars34 ratings              468.0
# 1  English   4.5 out of 5 stars41 ratings              820.0
# 2  English   4.5 out of 5 stars38 ratings              410.0
# 3  English   4.5 out of 5 stars12 ratings              615.0
# 4  English  4.5 out of 5 stars181 ratings              820.0
#
#   author_first_name author_last_name narrator_first_name narrator_last_name
# 0          Geronimo          Stilton                Bill             Lobely
# 1              Rick          Riordan              Robbie            Daymond
# 2              Jeff           Kinney                 Dan            Russell
# 3              Rick          Riordan             Soneela            Nankani
# 4              Rick          Riordan               Jesse          Bernstein

# %%
audible_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 87489 non-null  object
#  1   time                 87489 non-null  object
#  2   releasedate          87489 non-null  datetime64[ns]
#  3   language             87489 non-null  object
#  4   stars                87489 non-null  object
#  5   price (in Rupees)    87489 non-null  float64
#  6   author_first_name    53853 non-null  object
#  7   author_last_name     52398 non-null  object
#  8   narrator_first_name  62198 non-null  object
#  9   narrator_last_name   61071 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 6.7+ MB

# %% [markdown]
# - language to categorical
# - and time stars ratings price to int or float

# %%
audible_df['language'].value_counts()
# Out:
# language
# English             61884
# german               8295
# spanish              3496
# japanese             3167
# italian              2694
# french               2386
# russian              1804
# danish                935
# portuguese            526
# swedish               515
# Hindi                 436
# polish                224
# finnish               197
# dutch                 190
# tamil                 161
# catalan               153
# mandarin_chinese       97
# icelandic              52
# romanian               50
# hungarian              36
# urdu                   34
# afrikaans              28
# czech                  23
# turkish                20
# greek                  18
# arabic                 16
# norwegian              16
# galician               10
# bulgarian               9
# korean                  4
# slovene                 4
# hebrew                  2
# basque                  2
# telugu                  2
# lithuanian              2
# ukrainian               1
# Name: count, dtype: int64

# %%
audible_df['language'] = audible_df['language'].astype(dtype='category')

# %%
audible_df['time'].value_counts().sample(15)
# Out:
# time
# 37 hrs and 3 mins       1
# 57 mins               166
# 4 hrs and 32 mins     109
# 16 hrs and 37 mins     11
# 27 hrs and 40 mins      3
# 1 hr and 32 mins       95
# 38 mins               188
# 16 hrs and 5 mins      15
# 4 hrs and 14 mins      83
# 33 hrs and 10 mins      2
# 10 hrs and 40 mins     82
# 8 hrs and 18 mins      99
# 17 hrs and 56 mins      8
# 11 hrs and 35 mins     54
# 11 hrs and 42 mins     59
# Name: count, dtype: int64

# %%
def time_calculator(hour_time):
    hour_time = hour_time.split()
    if 'Less' in hour_time:
        return int(hour_time[2])
    elif 'hrs' in hour_time and 'mins' in hour_time:
        hours = int(hour_time[0])
        minutes = int(hour_time[3])
        return (hours * 60) + minutes
    else:
        return int(hour_time[0])
        
        
print(time_calculator('37 hrs and 3 mins'))
print(time_calculator('40 mins'))
# Out:
# 2223
# 40

# %%
audible_df['time'] = audible_df['time'].apply(time_calculator)
audible_df.rename(columns={'time':'time (in minutes)'}, inplace=True)
audible_df.head()
# Out:
#                                          name  time (in minutes) releasedate  \
# 0                  Geronimo Stilton #11 & #12                140  2008-08-04
# 1                            The Burning Maze                788  2018-05-01
# 2                                The Deep End                123  2020-11-06
# 3                        Daughter of the Deep                676  2021-10-05
# 4  The Lightning Thief: Percy Jackson, Book 1                 10  2010-01-13
#
#   language                          stars  price (in Rupees)  \
# 0  English     5 out of 5 stars34 ratings              468.0
# 1  English   4.5 out of 5 stars41 ratings              820.0
# 2  English   4.5 out of 5 stars38 ratings              410.0
# 3  English   4.5 out of 5 stars12 ratings              615.0
# 4  English  4.5 out of 5 stars181 ratings              820.0
#
#   author_first_name author_last_name narrator_first_name narrator_last_name
# 0          Geronimo          Stilton                Bill             Lobely
# 1              Rick          Riordan              Robbie            Daymond
# 2              Jeff           Kinney                 Dan            Russell
# 3              Rick          Riordan             Soneela            Nankani
# 4              Rick          Riordan               Jesse          Bernstein

# %%
audible_df['stars'].value_counts().sample(10)
# Out:
# stars
# 4.5 out of 5 stars41 ratings     16
# 4.5 out of 5 stars747 ratings     1
# 5 out of 5 stars18 ratings       18
# 4.5 out of 5 stars62 ratings      9
# 5 out of 5 stars1,425 ratings     1
# 5 out of 5 stars35 ratings        2
# 4.5 out of 5 stars511 ratings     1
# 5 out of 5 stars91 ratings        1
# 4 out of 5 stars120 ratings       1
# 5 out of 5 stars159 ratings       1
# Name: count, dtype: int64

# %%
def stars_split(row):
    
    if "Not" in row:
        return "Not rated yet", 0
    
    row = row.split()

    if ',' in row[4][5:]:
        row[4] = row[4].replace(',','')
    
    return float(row[0]), int(row[4][5:])
    
print(stars_split('Not rated yet'))
print(stars_split('4.5 out of 5 stars2 ratings'))
print(stars_split('5 out of 5 stars1,425 ratings'))
# Out:
# ('Not rated yet', 0)
# (4.5, 2)
# (5.0, 1425)

# %%
audible_df['stars'].apply(stars_split)
# Out:
# 0                 (5.0, 34)
# 1                 (4.5, 41)
# 2                 (4.5, 38)
# 3                 (4.5, 12)
# 4                (4.5, 181)
#                 ...
# 87484    (Not rated yet, 0)
# 87485    (Not rated yet, 0)
# 87486    (Not rated yet, 0)
# 87487    (Not rated yet, 0)
# 87488    (Not rated yet, 0)
# Name: stars, Length: 87489, dtype: object

# %%
audible_df[['stars_out_of_five','ratings']] = pd.DataFrame(audible_df['stars'].apply(stars_split).tolist(), index=audible_df.index)

# %%
audible_df.drop(columns='stars', inplace=True)
audible_df.head()
# Out:
#                                          name  time (in minutes) releasedate  \
# 0                  Geronimo Stilton #11 & #12                140  2008-08-04
# 1                            The Burning Maze                788  2018-05-01
# 2                                The Deep End                123  2020-11-06
# 3                        Daughter of the Deep                676  2021-10-05
# 4  The Lightning Thief: Percy Jackson, Book 1                 10  2010-01-13
#
#   language  price (in Rupees) author_first_name author_last_name  \
# 0  English              468.0          Geronimo          Stilton
# 1  English              820.0              Rick          Riordan
# 2  English              410.0              Jeff           Kinney
# 3  English              615.0              Rick          Riordan
# 4  English              820.0              Rick          Riordan
#
#   narrator_first_name narrator_last_name stars_out_of_five  ratings
# 0                Bill             Lobely               5.0       34
# 1              Robbie            Daymond               4.5       41
# 2                 Dan            Russell               4.5       38
# 3             Soneela            Nankani               4.5       12
# 4               Jesse          Bernstein               4.5      181
